# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fifa.csv')

# %%
#mostrar filas y columnas
df.shape
# Out:
# (64, 88)

# %%
#leer la tabla
df
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
#visualizar los tipos de datos y datos perdidos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %%
df.describe()
# Out:
#        number of goals team1  number of goals team2  total attempts team1  \
# count              64.000000              64.000000             64.000000
# mean                1.578125               1.109375             11.140625
# std                 1.551289               1.055856              4.972519
# min                 0.000000               0.000000              2.000000
# 25%                 0.000000               0.000000              8.000000
# 50%                 1.000000               1.000000             10.000000
# 75%                 2.000000               2.000000             14.000000
# max                 7.000000               4.000000             25.000000
#
#        total attempts team2  conceded team1  conceded team2  \
# count             64.000000       64.000000       64.000000
# mean              11.281250        1.109375        1.578125
# std                5.807682        1.055856        1.551289
# ...

# %%
#limpiando datos de columnas: possession team1, possession team2
df['possession team1'] = df['possession team1'].str.replace('%','')
df['possession team2'] = df['possession team2'].str.replace('%','')

# %%
#transformando el campo 'date' de cadena(object) a datetime64
df['date'] = df['date'].astype('datetime64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     datetime64[ns]
# ...

# %%
#contar veces que aparece un equipo en 'team1'
part_jugados_t1 = df['team1'].value_counts()
print(part_jugados_t1)

#contar veces que aparece un equipo en 'team2'
part_jugados_t2 = df['team2'].value_counts()
print(part_jugados_t2)
# Out:
# ARGENTINA         5
# CROATIA           4
# FRANCE            4
# NETHERLANDS       4
# ENGLAND           4
# PORTUGAL          3
# JAPAN             3
# MOROCCO           3
# BRAZIL            3
# QATAR             2
# KOREA REPUBLIC    2
# CAMEROON          2
# POLAND            2
# TUNISIA           2
# WALES             2
# BELGIUM           2
# SPAIN             2
# URUGUAY           1
# IRAN              1
# GHANA             1
# COSTA RICA        1
# CANADA            1
# SAUDI ARABIA      1
# AUSTRALIA         1
# SENEGAL           1
# ECUADOR           1
# SWITZERLAND       1
# UNITED STATES     1
# DENMARK           1
# MEXICO            1
# GERMANY           1
# SERBIA            1
# Name: team1, dtype: int64
# MOROCCO           4
# SENEGAL           3
# FRANCE            3
# AUSTRALIA         3
# CROATIA           3
# SWITZERLAND       3
# UNITED STATES     3
# IRAN              2
# PORTUGAL          2
# SPAIN             2
# ARGENTINA         2
# URUGUAY           2
# ...

# %%
#suma de partidos jugados de Team 1 y Team 2
part_jugados_tot = part_jugados_t1 + part_jugados_t2 

#ordenar partidos jugados por país
part_jugados_tot_ord = part_jugados_tot.sort_values(ascending=False)
print(part_jugados_tot_ord)
# Out:
# ARGENTINA         7
# CROATIA           7
# FRANCE            7
# MOROCCO           7
# BRAZIL            5
# PORTUGAL          5
# ENGLAND           5
# NETHERLANDS       5
# JAPAN             4
# UNITED STATES     4
# SWITZERLAND       4
# SPAIN             4
# SENEGAL           4
# POLAND            4
# AUSTRALIA         4
# KOREA REPUBLIC    4
# IRAN              3
# MEXICO            3
# GHANA             3
# GERMANY           3
# ECUADOR           3
# DENMARK           3
# QATAR             3
# SAUDI ARABIA      3
# COSTA RICA        3
# SERBIA            3
# CANADA            3
# CAMEROON          3
# TUNISIA           3
# BELGIUM           3
# URUGUAY           3
# WALES             3
# dtype: int64

# %%
g1 = part_jugados_tot_ord 
g1.plot(kind='bar', figsize=(15,8), color='#690A2E',
       edgecolor='#EDEAE8',
       width=0.5,
       lw=2)

plt.title('Partidos jugados por país - Mundial Qatar 2022')
plt.xlabel('Países')
plt.ylabel('Partidos jugados')
# Out:
# Text(0, 0.5, 'Partidos jugados')

# %%
#la información inicial fue brindada por 'team1' y 'team2'. 
#De 'team1' se está identificando por fecha la cantidad de tarjetas amarillas
g2 = df.groupby(by='date')['yellow cards team1'].sum()
g2.plot(figsize=(15,10),
        color ='#C4102D', #color de linea
       lw = 3, #grosor de linea
       marker = 'o', #forma de puntero
       markerfacecolor='#EDEAE8', #color de puntero
       markersize=10
       )
# Out:
# <AxesSubplot: xlabel='date'>

# %% [markdown]
# ### Identificar cantidad de amarillas por equipo

# %%
#Para visualizar mejor, separo las columnas a necesitar en otra variable

df_amarillas = df[['team1','yellow cards team1','team2','yellow cards team2']]
df_amarillas
# Out:
#             team1  yellow cards team1         team2  yellow cards team2
# 0           QATAR                   4       ECUADOR                   2
# 1         ENGLAND                   0          IRAN                   2
# 2         SENEGAL                   2   NETHERLANDS                   1
# 3   UNITED STATES                   4         WALES                   2
# 4       ARGENTINA                   0  SAUDI ARABIA                   6
# ..            ...                 ...           ...                 ...
# 59        ENGLAND                   1        FRANCE                   3
# 60      ARGENTINA                   2       CROATIA                   2
# 61         FRANCE                   0       MOROCCO                   1
# 62        CROATIA                   0       MOROCCO                   2
# 63      ARGENTINA                   4        FRANCE                   3
#
# [64 rows x 4 columns]

# %%
t1 = df_amarillas.groupby('team1')['yellow cards team1'].sum()
t1
# Out:
# team1
# ARGENTINA          7
# AUSTRALIA          2
# BELGIUM            4
# BRAZIL             1
# CAMEROON           7
# CANADA             4
# COSTA RICA         1
# CROATIA            4
# DENMARK            2
# ECUADOR            0
# ENGLAND            1
# FRANCE             2
# GERMANY            0
# GHANA              2
# IRAN               3
# JAPAN              6
# KOREA REPUBLIC     4
# MEXICO             2
# MOROCCO            5
# NETHERLANDS       11
# POLAND             4
# PORTUGAL           5
# QATAR              7
# SAUDI ARABIA       6
# SENEGAL            2
# SERBIA             7
# SPAIN              1
# SWITZERLAND        2
# TUNISIA            4
# UNITED STATES      4
# URUGUAY            1
# WALES              3
# Name: yellow cards team1, dtype: int64

# %%
t2 = df_amarillas.groupby('team2')['yellow cards team2'].sum()
t2
# Out:
# team2
# ARGENTINA         9
# AUSTRALIA         5
# BELGIUM           1
# BRAZIL            5
# CAMEROON          1
# CANADA            4
# COSTA RICA        5
# CROATIA           4
# DENMARK           3
# ECUADOR           3
# ENGLAND           0
# FRANCE            6
# GERMANY           3
# GHANA             6
# IRAN              4
# JAPAN             0
# KOREA REPUBLIC    2
# MEXICO            5
# MOROCCO           4
# NETHERLANDS       1
# POLAND            3
# PORTUGAL          1
# QATAR             0
# SAUDI ARABIA      8
# SENEGAL           5
# SERBIA            5
# SPAIN             1
# SWITZERLAND       7
# TUNISIA           1
# UNITED STATES     1
# URUGUAY           7
# WALES             2
# Name: yellow cards team2, dtype: int64

# %%
tot_amarillas = t1 + t2

tot_amarillas_ord= tot_amarillas.sort_values(ascending=False)
print(tot_amarillas_ord)
# Out:
# team1
# ARGENTINA         16
# SAUDI ARABIA      14
# NETHERLANDS       12
# SERBIA            12
# MOROCCO            9
# SWITZERLAND        9
# GHANA              8
# FRANCE             8
# URUGUAY            8
# CROATIA            8
# CANADA             8
# CAMEROON           8
# SENEGAL            7
# IRAN               7
# POLAND             7
# AUSTRALIA          7
# MEXICO             7
# QATAR              7
# PORTUGAL           6
# KOREA REPUBLIC     6
# JAPAN              6
# COSTA RICA         6
# BRAZIL             6
# DENMARK            5
# TUNISIA            5
# UNITED STATES      5
# BELGIUM            5
# WALES              5
# GERMANY            3
# ECUADOR            3
# SPAIN              2
# ENGLAND            1
# dtype: int64

# %%
g2 = part_jugados_tot_ord 
g2.plot(kind='bar', figsize=(15,8), color='#690A2E',
       edgecolor='#EDEAE8',
       width=0.5,
       lw=2)

plt.title('Partidos jugados por país - Mundial Qatar 2022')
plt.xlabel('Países')
plt.ylabel('Partidos jugados')
